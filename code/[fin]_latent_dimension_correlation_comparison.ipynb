# %%
import numpy as np

# %% [markdown]
# # SE - latent dimension correlation comparison

# %%
## res - mm

## res-mm-method1-best1
correlation_matrix1 = np.array([
    [ 1.,         -0.16989383, -0.40071922, -0.31207698, -0.08475396],
    [-0.16989383,  1.,          0.50516099,  0.37197808, -0.05713703],
    [-0.40071922,  0.50516099,  1.,          0.87811357, -0.23301824],
    [-0.31207698,  0.37197808,  0.87811357,  1.,         -0.11183346],
    [-0.08475396, -0.05713703, -0.23301824, -0.11183346,  1.        ]
])

## res-mm-method1-best2
correlation_matrix2 = np.array([
    [ 1.,          0.33023841, -0.27611846, -0.39997989,  0.13483466],
    [ 0.33023841,  1.,         -0.27150449, -0.67782445, -0.13697377],
    [-0.27611846, -0.27150449,  1.,          0.49294685, -0.21667334],
    [-0.39997989, -0.67782445,  0.49294685,  1.,          0.05789381],
    [ 0.13483466, -0.13697377, -0.21667334,  0.05789381,  1.        ]
])

## res-mm-method3-best1
correlation_matrix3 = np.array([
    [ 1.,         -0.46536019, -0.17613831,  0.386343,    0.1593035 ],
    [-0.46536019,  1.,          0.12871877,  0.16985815, -0.01367104],
    [-0.17613831,  0.12871877,  1.,         -0.13108603, -0.71509113],
    [ 0.386343,    0.16985815, -0.13108603,  1.,          0.02495951],
    [ 0.1593035,  -0.01367104, -0.71509113,  0.02495951,  1.        ]
])

## res-mm-method3-best2
correlation_matrix4 = np.array([
    [ 1.,         -0.03277693,  0.38937205,  0.21014547, -0.35259869],
    [-0.03277693,  1.,          0.66381462,  0.10107188,  0.18910883],
    [ 0.38937205,  0.66381462,  1.,         -0.12258518, -0.16552352],
    [ 0.21014547,  0.10107188, -0.12258518,  1.,          0.02782786],
    [-0.35259869,  0.18910883, -0.16552352,  0.02782786,  1.        ]
])

def calculate_metrics(matrix):
    # Remove diagonal elements (self-correlations)
    off_diagonal = matrix[np.triu_indices_from(matrix, k=1)]

    # Average absolute correlation
    avg_abs_corr = np.mean(np.abs(off_diagonal))

    # Variance of correlations
    variance_corr = np.var(off_diagonal)

    # Frobenius norm of the off-diagonal elements
    frobenius_norm = np.linalg.norm(off_diagonal)

    return avg_abs_corr, variance_corr, frobenius_norm

# Calculate metrics for each matrix
metrics1 = calculate_metrics(correlation_matrix1)
metrics2 = calculate_metrics(correlation_matrix2)
metrics3 = calculate_metrics(correlation_matrix3)
metrics4 = calculate_metrics(correlation_matrix4)

# Print the results
print("res-mm-method1-best1 Metrics:")
print(f"Average Absolute Correlation: {metrics1[0]:.4f}")
print(f"Variance of Correlation: {metrics1[1]:.4f}")

print("\nres-mm-method1-best2 Metrics:")
print(f"Average Absolute Correlation: {metrics2[0]:.4f}")
print(f"Variance of Correlation: {metrics2[1]:.4f}")

print("\nres-mm-method3-best1 Metrics:")
print(f"Average Absolute Correlation: {metrics3[0]:.4f}")
print(f"Variance of Correlation: {metrics3[1]:.4f}")

print("\nres-mm-method3-best2 Metrics:")
print(f"Average Absolute Correlation: {metrics4[0]:.4f}")
print(f"Variance of Correlation: {metrics4[1]:.4f}")
# Out:
# res-mm-method1-best1 Metrics:
# Average Absolute Correlation: 0.3125
# Variance of Correlation: 0.1514
#
# res-mm-method1-best2 Metrics:
# Average Absolute Correlation: 0.2995
# Variance of Correlation: 0.1116
#
# res-mm-method3-best1 Metrics:
# Average Absolute Correlation: 0.2371
# Variance of Correlation: 0.0957
#
# res-mm-method3-best2 Metrics:
# Average Absolute Correlation: 0.2255
# Variance of Correlation: 0.0769

# %%
## res - ss

## res-ss-method1-best1
correlation_matrix1 = np.array([
    [ 1.,          0.30797033,  0.54945184,  0.0214523,   0.25289563],
    [ 0.30797033,  1.,          0.58627533,  0.14808727,  0.30258413],
    [ 0.54945184,  0.58627533,  1.,          0.02314082,  0.02965746],
    [ 0.0214523,   0.14808727,  0.02314082,  1.,         -0.34512566],
    [ 0.25289563,  0.30258413,  0.02965746, -0.34512566,  1.        ]
])

## res-ss-method1-best2
correlation_matrix2 = np.array([
    [ 1.,          0.29696144, -0.1367382,   0.52200028],
    [ 0.29696144,  1.,         -0.16077114,  0.74088074],
    [-0.1367382,  -0.16077114,  1.,         -0.21152383],
    [ 0.52200028,  0.74088074, -0.21152383,  1.        ]
])


## res-ss-method3-best1
correlation_matrix3 = np.array([
    [ 1.,          0.19574385,  0.34091679, -0.25850344],
    [ 0.19574385,  1.,         -0.01460667, -0.13430074],
    [ 0.34091679, -0.01460667,  1.,          0.08144593],
    [-0.25850344, -0.13430074,  0.08144593,  1.        ]
])

## res-ss-method3-best2
correlation_matrix4 = np.array([
    [ 1.,         -0.05741718, -0.23807442,  0.08793147, -0.03243081],
    [-0.05741718,  1.,          0.2016903,  -0.14877315,  0.16399051],
    [-0.23807442,  0.2016903,   1.,         -0.52844769,  0.21047439],
    [ 0.08793147, -0.14877315, -0.52844769,  1.,         -0.11207877],
    [-0.03243081,  0.16399051,  0.21047439, -0.11207877,  1.        ]
])


def calculate_metrics(matrix):
    # Remove diagonal elements (self-correlations)
    off_diagonal = matrix[np.triu_indices_from(matrix, k=1)]

    # Average absolute correlation
    avg_abs_corr = np.mean(np.abs(off_diagonal))

    # Variance of correlations
    variance_corr = np.var(off_diagonal)

    # Frobenius norm of the off-diagonal elements
    frobenius_norm = np.linalg.norm(off_diagonal)

    return avg_abs_corr, variance_corr, frobenius_norm

# Calculate metrics for each matrix
metrics1 = calculate_metrics(correlation_matrix1)
metrics2 = calculate_metrics(correlation_matrix2)
metrics3 = calculate_metrics(correlation_matrix3)
metrics4 = calculate_metrics(correlation_matrix4)

# Print the results
print("res-ss-method1-best1 Metrics:")
print(f"Average Absolute Correlation: {metrics1[0]:.4f}")
print(f"Variance of Correlation: {metrics1[1]:.4f}")

print("\nres-ss-method1-best2 Metrics:")
print(f"Average Absolute Correlation: {metrics2[0]:.4f}")
print(f"Variance of Correlation: {metrics2[1]:.4f}")

print("\nres-ss-method3-best1 Metrics:")
print(f"Average Absolute Correlation: {metrics3[0]:.4f}")
print(f"Variance of Correlation: {metrics3[1]:.4f}")

print("\nres-ss-method3-best2 Metrics:")
print(f"Average Absolute Correlation: {metrics4[0]:.4f}")
print(f"Variance of Correlation: {metrics4[1]:.4f}")
# Out:
# res-ss-method1-best1 Metrics:
# Average Absolute Correlation: 0.2567
# Variance of Correlation: 0.0687
#
# res-ss-method1-best2 Metrics:
# Average Absolute Correlation: 0.3448
# Variance of Correlation: 0.1358
#
# res-ss-method3-best1 Metrics:
# Average Absolute Correlation: 0.1709
# Variance of Correlation: 0.0398
#
# res-ss-method3-best2 Metrics:
# Average Absolute Correlation: 0.1781
# Variance of Correlation: 0.0474

# %%
## mod - ss


## mod-ss-method1-best1
correlation_matrix1 = np.array([
    [ 1.,         -0.42522991, -0.55274599,  0.71814241, -0.67488728],
    [-0.42522991,  1.,         -0.0051193,  -0.51272477,  0.24704451],
    [-0.55274599, -0.0051193,   1.,         -0.52047143,  0.61996209],
    [ 0.71814241, -0.51272477, -0.52047143,  1.,         -0.56127025],
    [-0.67488728,  0.24704451,  0.61996209, -0.56127025,  1.        ]
])

## mod-ss-method1-best2
correlation_matrix2 = np.array([
    [ 1.,          0.24885691,  0.02348047],
    [ 0.24885691,  1.,         -0.54123424],
    [ 0.02348047, -0.54123424,  1.        ]
])


## mod-ss-method3-best1
correlation_matrix3 = np.array([
    [ 1.,          0.01563735,  0.08845119,  0.47797774,  0.23262205],
    [ 0.01563735,  1.,          0.00298947,  0.36033671, -0.02047094],
    [ 0.08845119,  0.00298947,  1.,          0.46411566,  0.40291995],
    [ 0.47797774,  0.36033671,  0.46411566,  1.,          0.39900081],
    [ 0.23262205, -0.02047094,  0.40291995,  0.39900081,  1.        ]
])

## mod-ss-method3-best2
correlation_matrix4 = np.array([
    [ 1.,         -0.47074008, -0.08920948, -0.08574593, -0.23235335],
    [-0.47074008,  1.,         -0.28753228, -0.02662083,  0.47915895],
    [-0.08920948, -0.28753228,  1.,         -0.26569227, -0.06627331],
    [-0.08574593, -0.02662083, -0.26569227,  1.,          0.02860696],
    [-0.23235335,  0.47915895, -0.06627331,  0.02860696,  1.        ]
])


def calculate_metrics(matrix):
    # Remove diagonal elements (self-correlations)
    off_diagonal = matrix[np.triu_indices_from(matrix, k=1)]

    # Average absolute correlation
    avg_abs_corr = np.mean(np.abs(off_diagonal))

    # Variance of correlations
    variance_corr = np.var(off_diagonal)

    # Frobenius norm of the off-diagonal elements
    frobenius_norm = np.linalg.norm(off_diagonal)

    return avg_abs_corr, variance_corr, frobenius_norm

# Calculate metrics for each matrix
metrics1 = calculate_metrics(correlation_matrix1)
metrics2 = calculate_metrics(correlation_matrix2)
metrics3 = calculate_metrics(correlation_matrix3)
metrics4 = calculate_metrics(correlation_matrix4)

# Print the results
print("mod-ss-method1-best1 Metrics:")
print(f"Average Absolute Correlation: {metrics1[0]:.4f}")
print(f"Variance of Correlation: {metrics1[1]:.4f}")

print("\nmod-ss-method1-best2 Metrics:")
print(f"Average Absolute Correlation: {metrics2[0]:.4f}")
print(f"Variance of Correlation: {metrics2[1]:.4f}")

print("\nmod-ss-method3-best1 Metrics:")
print(f"Average Absolute Correlation: {metrics3[0]:.4f}")
print(f"Variance of Correlation: {metrics3[1]:.4f}")

print("\nmod-ss-method3-best2 Metrics:")
print(f"Average Absolute Correlation: {metrics4[0]:.4f}")
print(f"Variance of Correlation: {metrics4[1]:.4f}")
# Out:
# mod-ss-method1-best1 Metrics:
# Average Absolute Correlation: 0.4838
# Variance of Correlation: 0.2474
#
# mod-ss-method1-best2 Metrics:
# Average Absolute Correlation: 0.2712
# Variance of Correlation: 0.1104
#
# mod-ss-method3-best1 Metrics:
# Average Absolute Correlation: 0.2465
# Variance of Correlation: 0.0370
#
# mod-ss-method3-best2 Metrics:
# Average Absolute Correlation: 0.2032
# Variance of Correlation: 0.0576

# %%
## mod - mm


## mod - mm-method1-best1
correlation_matrix1 = np.array([
    [ 1.,          0.27341915,  0.5457976,  -0.61524119, -0.55066915],
    [ 0.27341915,  1.,         -0.1533339,  -0.29539084, -0.0314978 ],
    [ 0.5457976,  -0.1533339,   1.,         -0.48274557, -0.38345682],
    [-0.61524119, -0.29539084, -0.48274557,  1.,          0.8591797 ],
    [-0.55066915, -0.0314978,  -0.38345682,  0.8591797,   1.        ]
])

## mod - mm-method1-best2
correlation_matrix2 = np.array([
    [ 1.,          0.90913048, -0.62404316, -0.25591497,  0.40747206],
    [ 0.90913048,  1.,         -0.73806515, -0.43251889,  0.26207923],
    [-0.62404316, -0.73806515,  1.,          0.50456251, -0.28659933],
    [-0.25591497, -0.43251889,  0.50456251,  1.,          0.08879892],
    [ 0.40747206,  0.26207923, -0.28659933,  0.08879892,  1.        ]
])


## mod - mm-method3-best1
correlation_matrix3 = np.array([
    [ 1.,         -0.21559774, -0.37336696,  0.36021264, -0.23835218],
    [-0.21559774,  1.,          0.17705809,  0.10282089, -0.42454685],
    [-0.37336696,  0.17705809,  1.,          0.01535451,  0.15280912],
    [ 0.36021264,  0.10282089,  0.01535451,  1.,         -0.25548381],
    [-0.23835218, -0.42454685,  0.15280912, -0.25548381,  1.        ]
])

## mod - mm-method3-best2
correlation_matrix4 = np.array([
    [ 1.,         -0.29614563,  0.59267155, -0.29757324],
    [-0.29614563,  1.,         -0.02364822, -0.20476406],
    [ 0.59267155, -0.02364822,  1.,         -0.42211233],
    [-0.29757324, -0.20476406, -0.42211233,  1.        ]
])


def calculate_metrics(matrix):
    # Remove diagonal elements (self-correlations)
    off_diagonal = matrix[np.triu_indices_from(matrix, k=1)]

    # Average absolute correlation
    avg_abs_corr = np.mean(np.abs(off_diagonal))

    # Variance of correlations
    variance_corr = np.var(off_diagonal)

    # Frobenius norm of the off-diagonal elements
    frobenius_norm = np.linalg.norm(off_diagonal)

    return avg_abs_corr, variance_corr, frobenius_norm

# Calculate metrics for each matrix
metrics1 = calculate_metrics(correlation_matrix1)
metrics2 = calculate_metrics(correlation_matrix2)
metrics3 = calculate_metrics(correlation_matrix3)
metrics4 = calculate_metrics(correlation_matrix4)

# Print the results
print("mod-mm-method1-best1 Metrics:")
print(f"Average Absolute Correlation: {metrics1[0]:.4f}")
print(f"Variance of Correlation: {metrics1[1]:.4f}")

print("\nmod-mm-method1-best2 Metrics:")
print(f"Average Absolute Correlation: {metrics2[0]:.4f}")
print(f"Variance of Correlation: {metrics2[1]:.4f}")

print("\nmod-mm-method3-best1 Metrics:")
print(f"Average Absolute Correlation: {metrics3[0]:.4f}")
print(f"Variance of Correlation: {metrics3[1]:.4f}")

print("\nmod-mm-method3-best2 Metrics:")
print(f"Average Absolute Correlation: {metrics4[0]:.4f}")
print(f"Variance of Correlation: {metrics4[1]:.4f}")
# Out:
# mod-mm-method1-best1 Metrics:
# Average Absolute Correlation: 0.4191
# Variance of Correlation: 0.2215
#
# mod-mm-method1-best2 Metrics:
# Average Absolute Correlation: 0.4509
# Variance of Correlation: 0.2590
#
# mod-mm-method3-best1 Metrics:
# Average Absolute Correlation: 0.2316
# Variance of Correlation: 0.0635
#
# mod-mm-method3-best2 Metrics:
# Average Absolute Correlation: 0.3062
# Variance of Correlation: 0.1129

# %% [markdown]
# # ENV - latent dimension correlation comparison

# %%
## ss

##ss method1 best1
correlation_matrix1 = np.array([
    [1., -0.31142513, 0.12038532, -0.7827916],
    [-0.31142513, 1., -0.21834381, -0.21059738],
    [0.12038532, -0.21834381, 1., -0.09728847],
    [-0.7827916, -0.21059738, -0.09728847, 1.]
])

## ss method1 best2
correlation_matrix2 = np.array([
    [1., -0.19770959, -0.0084177],
    [-0.19770959, 1., 0.32982928],
    [-0.0084177, 0.32982928, 1.]
])

##ss method3 best1
correlation_matrix3 = np.array([
    [1.,         0.25143366, 0.18116786, 0.43535495],
    [0.25143366, 1.,         0.08490143, 0.13977177],
    [0.18116786, 0.08490143, 1.,         0.3420611 ],
    [0.43535495, 0.13977177, 0.3420611,  1.        ]
])

##ss method3 best2
correlation_matrix4 = np.array([
    [ 1.,         -0.42658854, -0.08541906],
    [-0.42658854,  1.,          0.01507296],
    [-0.08541906,  0.01507296,  1.        ]
])

def calculate_metrics(matrix):
    # Remove diagonal elements (self-correlations)
    off_diagonal = matrix[np.triu_indices_from(matrix, k=1)]

    # Average absolute correlation
    avg_abs_corr = np.mean(np.abs(off_diagonal))

    # Variance of correlations
    variance_corr = np.var(off_diagonal)

    # Frobenius norm of the off-diagonal elements
    frobenius_norm = np.linalg.norm(off_diagonal)

    return avg_abs_corr, variance_corr, frobenius_norm

# Calculate metrics for each matrix
metrics1 = calculate_metrics(correlation_matrix1)
metrics2 = calculate_metrics(correlation_matrix2)
metrics3 = calculate_metrics(correlation_matrix3)
metrics4 = calculate_metrics(correlation_matrix4)

# Print the results
print("Model 1 Metrics:")
print(f"Average Absolute Correlation: {metrics1[0]:.4f}")
print(f"Variance of Correlation: {metrics1[1]:.4f}")

print("\nModel 2 Metrics:")
print(f"Average Absolute Correlation: {metrics2[0]:.4f}")
print(f"Variance of Correlation: {metrics2[1]:.4f}")

print("Model 3 Metrics:")
print(f"Average Absolute Correlation: {metrics3[0]:.4f}")
print(f"Variance of Correlation: {metrics3[1]:.4f}")

print("\nModel 4 Metrics:")
print(f"Average Absolute Correlation: {metrics4[0]:.4f}")
print(f"Variance of Correlation: {metrics4[1]:.4f}")
# Out:
# Model 1 Metrics:
# Average Absolute Correlation: 0.2901
# Variance of Correlation: 0.0751
#
# Model 2 Metrics:
# Average Absolute Correlation: 0.1787
# Variance of Correlation: 0.0476
# Model 3 Metrics:
# Average Absolute Correlation: 0.2391
# Variance of Correlation: 0.0144
#
# Model 4 Metrics:
# Average Absolute Correlation: 0.1757
# Variance of Correlation: 0.0357

# %%
#env mm correlation


##mm method1 best1
correlation_matrix1 = np.array([
    [ 1.,         -0.45445476, -0.78403224, -0.12217755],
    [-0.45445476,  1.,         -0.16160395,  0.30703635],
    [-0.78403224, -0.16160395,  1.,          0.10416305],
    [-0.12217755,  0.30703635,  0.10416305,  1.        ]
])
## mm method1 best2
correlation_matrix2 = np.array([
    [ 1.,         -0.21453063,  0.40298506],
    [-0.21453063,  1.,         -0.40378934],
    [ 0.40298506, -0.40378934,  1.        ]
])
##mm method3 best1
correlation_matrix3 = np.array([
    [ 1.,         -0.15442104,  0.1122028,  -0.27715589],
    [-0.15442104,  1.,         -0.21135118, -0.01751638],
    [ 0.1122028,  -0.21135118,  1.,          0.17355153],
    [-0.27715589, -0.01751638,  0.17355153,  1.        ]
])
## mm method3 best2
correlation_matrix4 = np.array([
    [ 1.,          0.12469219,  0.04857673],
    [ 0.12469219,  1.,         -0.00981067],
    [ 0.04857673, -0.00981067,  1.        ]
])

def calculate_metrics(matrix):
    # Remove diagonal elements (self-correlations)
    off_diagonal = matrix[np.triu_indices_from(matrix, k=1)]

    # Average absolute correlation
    avg_abs_corr = np.mean(np.abs(off_diagonal))

    # Variance of correlations
    variance_corr = np.var(off_diagonal)

    # Frobenius norm of the off-diagonal elements
    frobenius_norm = np.linalg.norm(off_diagonal)

    return avg_abs_corr, variance_corr, frobenius_norm

# Calculate metrics for each matrix
metrics1 = calculate_metrics(correlation_matrix1)
metrics2 = calculate_metrics(correlation_matrix2)
metrics3 = calculate_metrics(correlation_matrix3)
metrics4 = calculate_metrics(correlation_matrix4)

# Print the results
print("Model 1 Metrics:")
print(f"Average Absolute Correlation: {metrics1[0]:.4f}")
print(f"Variance of Correlation: {metrics1[1]:.4f}")

print("\nModel 2 Metrics:")
print(f"Average Absolute Correlation: {metrics2[0]:.4f}")
print(f"Variance of Correlation: {metrics2[1]:.4f}")

print("Model 3 Metrics:")
print(f"Average Absolute Correlation: {metrics3[0]:.4f}")
print(f"Variance of Correlation: {metrics3[1]:.4f}")

print("Model 4 Metrics:")
print(f"Average Absolute Correlation: {metrics4[0]:.4f}")
print(f"Variance of Correlation: {metrics4[1]:.4f}")
# Out:
# Model 1 Metrics:
# Average Absolute Correlation: 0.3222
# Variance of Correlation: 0.1269
#
# Model 2 Metrics:
# Average Absolute Correlation: 0.3404
# Variance of Correlation: 0.1187
# Model 3 Metrics:
# Average Absolute Correlation: 0.1577
# Variance of Correlation: 0.0275
# Model 4 Metrics:
# Average Absolute Correlation: 0.0610
# Variance of Correlation: 0.0030

# %% [markdown]
# # PHY - latent dimension correlation comparison

# %%
## mm method 1 best 1
correlation_matrix1 = np.array([
    [ 1.,         -0.14579583, -0.61019016,  0.3006241 ],
    [-0.14579583,  1.,          0.19292236, -0.12439314],
    [-0.61019016,  0.19292236,  1.,         -0.57178489],
    [ 0.3006241,  -0.12439314, -0.57178489,  1.        ]
])

## mm method 1 best 2
correlation_matrix2 = np.array([
    [ 1.,          0.05646785,  0.23932737, -0.60939367],
    [ 0.05646785,  1.,         -0.71114414,  0.49033197],
    [ 0.23932737, -0.71114414,  1.,         -0.32713269],
    [-0.60939367,  0.49033197, -0.32713269,  1.        ]
])


## mm method3 best 1
correlation_matrix3 = np.array([
    [ 1.,         -0.19774729, -0.22529448, -0.22059147],
    [-0.19774729,  1.,         -0.22702935, -0.25515636],
    [-0.22529448, -0.22702935,  1.,         -0.39376357],
    [-0.22059147, -0.25515636, -0.39376357,  1.        ]
])

## mm method 3 best 2
correlation_matrix4 = np.array([
    [ 1.,         -0.00318444, -0.49109656, -0.40318678],
    [-0.00318444,  1.,          0.34796365, -0.32661871],
    [-0.49109656,  0.34796365,  1.,         -0.37609145],
    [-0.40318678, -0.32661871, -0.37609145,  1.        ]
])


def calculate_metrics(matrix):
    # Remove diagonal elements (self-correlations)
    off_diagonal = matrix[np.triu_indices_from(matrix, k=1)]

    # Average absolute correlation
    avg_abs_corr = np.mean(np.abs(off_diagonal))

    # Variance of correlations
    variance_corr = np.var(off_diagonal)

    # Frobenius norm of the off-diagonal elements
    frobenius_norm = np.linalg.norm(off_diagonal)

    return avg_abs_corr, variance_corr, frobenius_norm

# Calculate metrics for each matrix
metrics1 = calculate_metrics(correlation_matrix1)
metrics2 = calculate_metrics(correlation_matrix2)
metrics3 = calculate_metrics(correlation_matrix3)
metrics4 = calculate_metrics(correlation_matrix4)



# Print the results
print("mm method 1 best 1:")
print(f"Average Absolute Correlation: {metrics1[0]:.4f}")
print(f"Variance of Correlation: {metrics1[1]:.4f}")

print("\nmm method 1 best 2:")
print(f"Average Absolute Correlation: {metrics2[0]:.4f}")
print(f"Variance of Correlation: {metrics2[1]:.4f}")

print("\nmm method3 best 1:")
print(f"Average Absolute Correlation: {metrics3[0]:.4f}")
print(f"Variance of Correlation: {metrics3[1]:.4f}")

print("\nmm method 3 best 2:")
print(f"Average Absolute Correlation: {metrics4[0]:.4f}")
print(f"Variance of Correlation: {metrics4[1]:.4f}")
# Out:
# mm method 1 best 1:
# Average Absolute Correlation: 0.3243
# Variance of Correlation: 0.1184
#
# mm method 1 best 2:
# Average Absolute Correlation: 0.4056
# Variance of Correlation: 0.1935
#
# mm method3 best 1:
# Average Absolute Correlation: 0.2533
# Variance of Correlation: 0.0042
#
# mm method 3 best 2:
# Average Absolute Correlation: 0.3247
# Variance of Correlation: 0.0853

# %%
## ss method 1 best 1
correlation_matrix1 = np.array([
    [1.,         0.61635163, 0.26750426],
    [0.61635163, 1.,         0.244703  ],
    [0.26750426, 0.244703,   1.        ]
])

## ss method 1 best 2
correlation_matrix2 = np.array([
    [ 1.00000000e+00,  6.93186445e-01,  3.23213563e-01, -4.24927139e-01],
    [ 6.93186445e-01,  1.00000000e+00, -3.69901700e-02, -5.60255071e-04],
    [ 3.23213563e-01, -3.69901700e-02,  1.00000000e+00, -3.22042351e-01],
    [-4.24927139e-01, -5.60255071e-04, -3.22042351e-01,  1.00000000e+00]
])


## ss method3 best 1
correlation_matrix3 = np.array([
    [ 1.,          0.61159197,  0.18047643,  0.31910098],
    [ 0.61159197,  1.,         -0.08225657,  0.10477074],
    [ 0.18047643, -0.08225657,  1.,          0.31985434],
    [ 0.31910098,  0.10477074,  0.31985434,  1.        ]
])

## ss method 3 best 2
correlation_matrix4 = np.array([
    [ 1.,          0.1164756,   0.41462969],
    [ 0.1164756,   1.,         -0.35532778],
    [ 0.41462969, -0.35532778,  1.        ]
])


def calculate_metrics(matrix):
    # Remove diagonal elements (self-correlations)
    off_diagonal = matrix[np.triu_indices_from(matrix, k=1)]

    # Average absolute correlation
    avg_abs_corr = np.mean(np.abs(off_diagonal))

    # Variance of correlations
    variance_corr = np.var(off_diagonal)

    # Frobenius norm of the off-diagonal elements
    frobenius_norm = np.linalg.norm(off_diagonal)

    return avg_abs_corr, variance_corr, frobenius_norm

# Calculate metrics for each matrix
metrics1 = calculate_metrics(correlation_matrix1)
metrics2 = calculate_metrics(correlation_matrix2)
metrics3 = calculate_metrics(correlation_matrix3)
metrics4 = calculate_metrics(correlation_matrix4)


# Print the results
print("ss method 1 best 1:")
print(f"Average Absolute Correlation: {metrics1[0]:.4f}")
print(f"Variance of Correlation: {metrics1[1]:.4f}")

print("\nss method 1 best 2:")
print(f"Average Absolute Correlation: {metrics2[0]:.4f}")
print(f"Variance of Correlation: {metrics2[1]:.4f}")

print("\nss method3 best 1:")
print(f"Average Absolute Correlation: {metrics3[0]:.4f}")
print(f"Variance of Correlation: {metrics3[1]:.4f}")

print("\nss method 3 best 2:")
print(f"Average Absolute Correlation: {metrics4[0]:.4f}")
print(f"Variance of Correlation: {metrics4[1]:.4f}")
# Out:
# ss method 1 best 1:
# Average Absolute Correlation: 0.3762
# Variance of Correlation: 0.0289
#
# ss method 1 best 2:
# Average Absolute Correlation: 0.3002
# Variance of Correlation: 0.1436
#
# ss method3 best 1:
# Average Absolute Correlation: 0.2697
# Variance of Correlation: 0.0461
#
# ss method 3 best 2:
# Average Absolute Correlation: 0.2955
# Variance of Correlation: 0.1005
